# %%
import pandas as pd
from datetime import datetime
data = pd.read_csv(r'C:\WORK_IAAC\submissions\Storytelling\fiesta_shapefiles\fiestasAll_timeline_fin.csv')
data.head()
# Out:
#    Unnamed: 0                           festival          localidad       lat  \
# 0           0  Semana Santa en Medina de Rioseco  Medina de Rioseco  41.88306
# 1           1            Corpus Christi en Béjar              Béjar  40.38472
# 2           2             Semana Santa en Vivero             Vivero  43.64806
# 3           3   Semana Santa en Medina del Campo   Medina del Campo  41.30861
# 4           4             Semana Santa en Hellín             Hellín  38.51222
#
#        lng                 status     est        prov           comunidad  \
# 0 -5.04278  interes internacional  2009.0  Valladolid      Castilla-León
# 1 -5.76194  interes internacional  2019.0   Salamanca      Castilla-León
# 2 -7.59000  interes internacional  2013.0        Lugo             Galicia
# 3 -4.91500  interes internacional  2011.0  Valladolid      Castilla-León
# 4 -1.70333  interes internacional  2007.0    Albacete  Castilla-La Mancha
#
#           end          st
# 0  2023-04-09  2023-04-02
# ...

# %%
data.keys()
# Out:
# Index(['Unnamed: 0', 'festival', 'localidad', 'lat', 'lng', 'status', 'est',
#        'prov', 'comunidad', 'end', 'st'],
#       dtype='object')

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)
data.head()
# Out:
#                             festival          localidad       lat      lng  \
# 0  Semana Santa en Medina de Rioseco  Medina de Rioseco  41.88306 -5.04278
# 1            Corpus Christi en Béjar              Béjar  40.38472 -5.76194
# 2             Semana Santa en Vivero             Vivero  43.64806 -7.59000
# 3   Semana Santa en Medina del Campo   Medina del Campo  41.30861 -4.91500
# 4             Semana Santa en Hellín             Hellín  38.51222 -1.70333
#
#                   status     est        prov           comunidad         end  \
# 0  interes internacional  2009.0  Valladolid      Castilla-León   2023-04-09
# 1  interes internacional  2019.0   Salamanca      Castilla-León   2023-06-08
# 2  interes internacional  2013.0        Lugo             Galicia  2023-04-09
# 3  interes internacional  2011.0  Valladolid      Castilla-León   2023-04-09
# 4  interes internacional  2007.0    Albacete  Castilla-La Mancha  2023-04-09
#
#            st
# 0  2023-04-02
# 1  2023-06-08
# ...

# %%
data.replace(',', '/', regex=True, inplace=True)
data.head()
# Out:
#                             festival          localidad       lat      lng  \
# 0  Semana Santa en Medina de Rioseco  Medina de Rioseco  41.88306 -5.04278
# 1            Corpus Christi en Béjar              Béjar  40.38472 -5.76194
# 2             Semana Santa en Vivero             Vivero  43.64806 -7.59000
# 3   Semana Santa en Medina del Campo   Medina del Campo  41.30861 -4.91500
# 4             Semana Santa en Hellín             Hellín  38.51222 -1.70333
#
#                   status     est        prov           comunidad         end  \
# 0  interes internacional  2009.0  Valladolid      Castilla-León   2023-04-09
# 1  interes internacional  2019.0   Salamanca      Castilla-León   2023-06-08
# 2  interes internacional  2013.0        Lugo             Galicia  2023-04-09
# 3  interes internacional  2011.0  Valladolid      Castilla-León   2023-04-09
# 4  interes internacional  2007.0    Albacete  Castilla-La Mancha  2023-04-09
#
#            st
# 0  2023-04-02
# 1  2023-06-08
# ...

# %%
data.to_csv(r'C:\WORK_IAAC\submissions\Storytelling\fiesta_shapefiles\fiestasAll_timeline_fin.csv', index=False)
