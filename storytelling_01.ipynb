# %%
import pandas as pd
import numpy as np
from deep_translator import GoogleTranslator

#translate whole xlsx, columns of economic categories: 'GCNAE', 'CCNAE', 'SCNAE', > translate unique items and replace within columns,
#convert 'COORD_X', 'COORD_Y' into float
#then save file with index_EN
df = pd.read_csv(r'C:\WORK_IAAC\submissions\Storytelling\Storytelling_SRC\Calendari_de_festes_locals_a_Catalunya.csv')
# df = pd.read_excel
df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34560 entries, 0 to 34559
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Any calendari                  34560 non-null  int64
#  1   Data                           34560 non-null  object
#  2   Ajuntament o nucli municipal   34552 non-null  object
#  3   Codi municipal                 34560 non-null  int64
#  4   Codi municipi INE              34560 non-null  int64
#  5   Pedania                        34560 non-null  int64
#  6   Festiu                         34560 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#    Any calendari        Data Ajuntament o nucli municipal   Codi municipal  \
# 0           2012  08/10/2012            Abella de la Conca        25001000
# 1           2012  28/05/2012            Abella de la Conca        25001000
# 2           2013  20/05/2013            Abella de la Conca        25001000
# 3           2013  07/10/2013            Abella de la Conca        25001000
# 4           2014  06/10/2014            Abella de la Conca        25001000
#
#    Codi municipi INE  Pedania       Festiu       lat      lng
# 0              25001        0  Festa local  42.16123  1.09206
# 1              25001        0  Festa local  42.16123  1.09206
# 2              25001        0  Festa local  42.16123  1.09206
# 3              25001        0  Festa local  42.16123  1.09206
# 4              25001        0  Festa local  42.16123  1.09206

# %%
df.keys()
# Out:
# Index(['Any calendari', 'Data', 'Ajuntament o nucli municipal ',
#        'Codi municipal', 'Codi municipi INE', 'Pedania', 'Festiu'],
#       dtype='object')

# %%
df['Ajuntament o nucli municipal '].unique()
# Out:
# array(['Abella de la Conca', 'Abrera', 'Adraén', ..., 'Vila-seca',
#        'Sant Martí de Riucorb', 'Destres, les'], dtype=object)

# %%
# df = df[df['Any calendari']=='2013']

# %%
df['lat'] = None
df['lng'] = None

# Loop through each row of the dataframe and get the latitude and longitude for each address
for index, row in df.iterrows():
    address = row['Ajuntament o nucli municipal ']
    g = geocoder.arcgis(address)
    df.at[index, 'lat'] = g.lat
    df.at[index, 'lng'] = g.lng
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9740\3228061341.py in <module>
#       5 for index, row in df.iterrows():
#       6     address = row['Ajuntament o nucli municipal ']
# ----> 7     g = geocoder.arcgis(address)
#       8     df.at[index, 'lat'] = g.lat
#       9     df.at[index, 'lng'] = g.lng
#
# ~\AppData\Roaming\Python\Python39\site-packages\geocoder\api.py in arcgis(location, **kwargs)
#     396     :param ``location``: Your search location you want geocoded.
#     397     """
# --> 398     return get(location, provider='arcgis', **kwargs)
#     399
#     400
#
# ~\AppData\Roaming\Python\Python39\site-packages\geocoder\api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
# ...

# %%
df.to_csv(r'C:\WORK_IAAC\submissions\Storytelling\Storytelling_SRC\fiestas_Cat.csv')

# %%
#translate whole xlsx, columns of economic categories: 'GCNAE', 'CCNAE', 'SCNAE', > translate unique items and replace within columns,
#convert 'COORD_X', 'COORD_Y' into float
#then save file with index_EN
dx = pd.read_excel(r'C:\WORK_IAAC\submissions\Storytelling\Storytelling_SRC\Calendario festivos Asturias.xlsx')
dx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AMBITO                 191 non-null    object
#  1   COMUNIDAD - MUNICIPIO  191 non-null    object
#  2   FECHA                  191 non-null    datetime64[ns]
#  3   FIESTA - LOCALIDAD     191 non-null    object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 6.1+ KB

# %%
dx.head()
# Out:
#         AMBITO                      COMUNIDAD - MUNICIPIO      FECHA  \
# 0   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-01-02
# 1   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-01-06
# 2   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-04-06
# 3   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-04-07
# 4   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-05-01
# 5   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-08-15
# 6   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-09-08
# 7   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-10-12
# 8   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-11-01
# 9   AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-12-06
# 10  AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-12-08
# 11  AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-12-25
# 12       LOCAL                                    ALLANDE 2023-07-10
# ...

# %%
#get coordinates
import geocoder
dx['lat'] = None
dx['lng'] = None

# Loop through each row of the dataframe and get the latitude and longitude for each address
for index, row in dx.iterrows():
    address = row['COMUNIDAD - MUNICIPIO']
    g = geocoder.arcgis(address)
    dx.at[index, 'lat'] = g.lat
    dx.at[index, 'lng'] = g.lng

# %%
dx.head()
# Out:
#        AMBITO                      COMUNIDAD - MUNICIPIO      FECHA  \
# 0  AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-01-02
# 1  AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-01-06
# 2  AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-04-06
# 3  AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-04-07
# 4  AUTONOMICO  COMUNIDAD AUTONOMA PRINCIPADO DE ASTURIAS 2023-05-01
#
#             FIESTA - LOCALIDAD       lat  lng
# 0  Lunes siguiente a Año Nuevo  43.33333 -6.0
# 1           Epifanía del Señor  43.33333 -6.0
# 2                 Jueves Santo  43.33333 -6.0
# 3                Viernes Santo  43.33333 -6.0
# 4           Fiesta del Trabajo  43.33333 -6.0

# %%
dx.to_csv(r'C:\WORK_IAAC\submissions\Storytelling\Storytelling_SRC\fiestas_Asturias.csv')
