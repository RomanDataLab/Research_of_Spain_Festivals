# %%
import pandas as pd
data = pd.read_csv(r'C:\WORK_IAAC\submissions\Storytelling\fiesta_shapefiles\top music festivals Spain.csv')
data.head()
# Out:
#                                       fiesta date_start2023 date_fin2023  \
# 0                  Primavera sound Barcelona     01/06/2023   10/06/2023
# 1                          Mad Cool Festival     06/07/2023   08/07/2023
# 2                                      Sonar     15/07/2023   17/07/2023
# 3                            Bilbao BBK Live     06/07/2023   08/07/2023
# 4  BIF: Festival International de Benicassim     13/07/2023   16/07/2023
#
#       localidad              provincia       comunidad        lat       lng  \
# 0     Barcelona              Barcelona       Catalonia  41.411459  2.224658
# 1        Madrid                 Madrid          Madrid  40.467830 -3.617307
# 2  L'Hospitalet              Barcelona       Catalonia  41.354694  2.127825
# 3        Bilbao                 Bilbao  Basque Country  43.258076 -2.963625
# 4    Benicassim  Castellon de la Plana      Valenciana  40.056978  0.071053
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fiesta                26 non-null     object
#  1   date_start2023        26 non-null     object
#  2   date_fin2023          26 non-null     object
#  3   localidad             26 non-null     object
#  4   provincia             26 non-null     object
#  5   comunidad             26 non-null     object
#  6   lat                   26 non-null     float64
#  7   lng                   26 non-null     float64
#  8   visitors 2022         26 non-null     int64
#  9   mlneuro_budget        26 non-null     float64
#  10  mlneuro_revenue 2022  26 non-null     float64
#  11  average ticket 2022   26 non-null     int64
#  12  web                   26 non-null     object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 2.8+ KB

# %%
from datetime import datetime
data['start'] = pd.to_datetime(data['date_start2023'], format='%d/%m/%Y')

# %%
data['end'] = pd.to_datetime(data['date_fin2023'], format='%d/%m/%Y')
data = data.drop(columns=['date_start2023','date_fin2023'])
data.head()
# Out:
#                                       fiesta     localidad  \
# 0                  Primavera sound Barcelona     Barcelona
# 1                          Mad Cool Festival        Madrid
# 2                                      Sonar  L'Hospitalet
# 3                            Bilbao BBK Live        Bilbao
# 4  BIF: Festival International de Benicassim    Benicassim
#
#                provincia       comunidad        lat       lng  visitors 2022  \
# 0              Barcelona       Catalonia  41.411459  2.224658         505700
# 1                 Madrid          Madrid  40.467830 -3.617307         310000
# 2              Barcelona       Catalonia  41.354694  2.127825         120000
# 3                 Bilbao  Basque Country  43.258076 -2.963625         115000
# 4  Castellon de la Plana      Valenciana  40.056978  0.071053         180000
#
#    mlneuro_budget  mlneuro_revenue 2022  average ticket 2022  \
# 0           50.00                 349.0                  325
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fiesta                26 non-null     object
#  1   localidad             26 non-null     object
#  2   provincia             26 non-null     object
#  3   comunidad             26 non-null     object
#  4   lat                   26 non-null     float64
#  5   lng                   26 non-null     float64
#  6   visitors 2022         26 non-null     int64
#  7   mlneuro_budget        26 non-null     float64
#  8   mlneuro_revenue 2022  26 non-null     float64
#  9   average ticket 2022   26 non-null     int64
#  10  web                   26 non-null     object
#  11  start                 26 non-null     datetime64[ns]
#  12  end                   26 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(2), object(5)
# memory usage: 2.8+ KB

# %%
data.to_csv(r'C:\WORK_IAAC\submissions\Storytelling\fiesta_shapefiles\top music festivals Spain.csv')
